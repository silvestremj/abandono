# %%
import sys
import os
# Truco para que el Notebook encuentre la carpeta 'src'
sys.path.append(os.path.abspath(os.path.join('..')))

from src.data_logic import IngestorDatos, PreparadorDatos

# Ejecución
ingestor = IngestorDatos()
datasets = ingestor.leer_datos()

preparador = PreparadorDatos(datasets)
df_final = preparador.ejecutar_preparacion()

print("¡Éxito! Tabla maestra creada.")
print(df_final[['n_siu', 'estudio', 'target']].head())
# Out:
# Cargando inscripciones desde LSE_Inscrip_Baja_Recibido.csv...
# Cargando notas_bimestre desde LSE_Notas_Estadistica_Bimestre.csv...
# Cargando actual desde LSE_Notas_Inscrip_Baja_Actual.xlsx...
# Tabla Maestra generada con 772 registros.
# ¡Éxito! Tabla maestra creada.
#      n_siu estudio  target
# 0  2653003    CESE     NaN
# 1  2653003   CEIOT     NaN
# 2  2653003     MSE     0.0
# 3  2682003    CESE     NaN
# 4  2682003   CEIOT     NaN
